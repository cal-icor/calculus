# %% [markdown]
# <div style="border: 3px solid; border-image: linear-gradient(to right, #001f4d, #7f00ff) 1; padding: 15px; border-radius: 12px; font-family:'Segoe UI', sans-serif;">
#   <div style="background: linear-gradient(to right, #0f2027, #203a43, #2c5364); color:white; padding: 15px; border-radius: 10px; font-family:'Segoe UI', sans-serif; margin-top: -10px">
#   <h2 style="margin:0; text-align: center;">Defining The Derivative</h2>
# </div>
#
# The goal of this assignment is to give students practice with finding the derivative and thinking about how the definition of the derivative was created to find the slope of the tangent line (or the slope of a curve at a point or the instantaneous rate of change):
#
#    [1. Secant Lines and Tangent Lines](#section1): the meaning of the tangent to a curve at a point and how to calculate the slope of a tangent line.
#
#    [2. Derivative of a Function at a Point](#section2): introduce to definition of derivative and use Python to compute the derivative of the function.
#
#    [3. Equation of Tangent Line](#section3): Explore how to find the equation of tangent line, how to plot the function and its tangent line by using Python
#
# </div>

# %% [markdown]
# <a id="section1"></a>
# <h1 style="border-left: 6px solid #2c5364; padding-left: 10px;">1. Secant Lines and Tangent Lines</h1>
#
# In Calculus, we are interested in understanding how functions change. Two fundametal ideas that help us explore this area are **secant lines** and **tangent lines**.
#
# Revisiting the notion of secant lines and tangent lines. A secant line is a line that intersects a curve at two points. It gives an average rate of change of the function between those two points. By picking a point $(a,f(a))$ and choosing a value of $x$ near $a$, the secant line will be the line drawn throung the points $(a, f(a))$ and $(x,f(x))$ (see picture below). The slope of this line is given by an equation in the form of a difference quotient:
#
# $$m_{sec} = \frac{f(x)-f(a)}{x-a}$$
#
# By replacing $x$ with $a+h$, where $h$ is a value close to $0$. We can rewrite the equation above to calculate the the slope of the line through two points $(a,f(a))$ and $(a+h, f(a+h))$:
#
# $$m_{sec} = \frac{f(a+h)-f(a)}{a+h-a} = \frac{f(a+h)-f(a)}{h}$$

# %% [markdown]
# <div style=" color: black; padding: 16px; border-radius: 10px; font-family:'Segoe UI', sans-serif; box-shadow: 0 0 10px #2c5364;">
#     <h2>Slope of Secant Line </h2>
#
# Let $f(x)$ be a function. The secant line between the points $(a,f(a))$ and $(x,f(x))$ on the graph of $f$ has a slope given by:
#
# $$m_{sec} = \frac{f(x)-f(a)}{x-a}$$
#
# If we let $x=a+h$, where $h \neq 0$, then:
#
# $$m_{sec} = \frac{f(a+h)-f(a)}{h}$$
#
# is a difference quotient with increment $h$
# </div>

# %% [markdown]
# ![Screenshot%202025-06-12%20at%204.49.57%E2%80%AFPM.png](attachment:Screenshot%202025-06-12%20at%204.49.57%E2%80%AFPM.png)

# %% [markdown]
# From the picture above, as the value of $x$ gets closer to $a$, the slope of the secant line becomes a better approximation of the function’s rate of change at $a$. In fact, the **secant lines** gradually become closer to the **tangent line** at $a$ which represents the limiting case of the secant slopes. Likewise, as $h$ approaches $0$, the secant lines get closer to the tangent line. The slope of the tangent line at $a$ gives the instantaneous rate of change of the function at that point (see picture below).

# %% [markdown]
# ![Screenshot%202025-06-12%20at%205.08.50%E2%80%AFPM.png](attachment:Screenshot%202025-06-12%20at%205.08.50%E2%80%AFPM.png)

# %% [markdown]
# <div style="width: 100%; height: 2px; background-color: #2c5364; margin: 20px 0;"></div>

# %% [markdown]
# <h2> Example #1.1</h2>
#
# Consider the function $f(x) = x^2$ and its tangent line at the point (1,1) are shown over increasingly smaller intervals around $x=1$. As the intervals become narrower, the graph of the function and its tangent line begin to overlap, meaning the tangent line provides a good estimate for the function's values when $x$ is near $1$. This shows that the graph of $f(x)$ looks almost linear very close to $x=1$.

# %% [markdown]
# ![Screenshot%202025-06-12%20at%205.34.29%E2%80%AFPM.png](attachment:Screenshot%202025-06-12%20at%205.34.29%E2%80%AFPM.png)

# %% [markdown]
# <div style=" color: black; padding: 16px; border-radius: 10px; font-family:'Segoe UI', sans-serif; box-shadow: 0 0 10px #2c5364;">
#     <h2> Slope of Tangent Line </h2>
#
#
# Consider the function $f(x)$ defined in an open interval containing $a$. The tangent line at $x=a$ has a slope given by the limit of the secant slope as $x \to a$:
#
# $$m_{tan} = \displaystyle\lim_{x \to a} \frac{f(x)-f(a)}{x-a}$$
#
# Or equivalently, using $h \to 0$:
#
# $$m_{tan} = \displaystyle\lim_{h \to 0} \frac{f(a+h)-f(a)}{h}$$
#
# </div>

# %% [markdown]
# <h2> Remark: </h2>
#
# The slope of the tangent line is defined using two different forms, just as the slope of a secant line is defined using two different formulas.  We use both definitions in this text.  As before, the setting will determine which definition is used.  We may now find equations of tangent lines using the formal definition of a tangent line to a function at a point.

# %% [markdown]
# <div style="width: 100%; height: 2px; background-color: #2c5364; margin: 20px 0;"></div>

# %% [markdown]
# <h2>Example #1.2: </h2>
#
# Consider the same function above $f(x) = x^2$, but we pick the point $(2,4)$ for this example. By taking the limit as $x$ approaches $2$, the point $(x,f(x))$ in the definition is getting closer and closer to the point $(2,4)$.
#
# <h2>Solution </h2>
#
# Let's find the limit:
#
# $$\displaystyle\lim_{x \to 2} \frac{f(a)-f(2)}{x-2} = \displaystyle\lim_{x \to 2} \frac{x^2-4}{x-2} = \displaystyle\lim_{x \to 2} \frac{(x+2)(x-2)}{x-2} = \displaystyle\lim_{x \to 2} (x+2) = 2 + 2 = 4$$
#
# This means that the true and exact slope of the curve (or slope of tangent line) at $x=2$ is 4.

# %% [markdown]
# ![Screenshot%202025-06-12%20at%205.45.05%E2%80%AFPM.png](attachment:Screenshot%202025-06-12%20at%205.45.05%E2%80%AFPM.png)

# %% [markdown]
# <h2>Python</h2>
#
# Let's explore this example using Python. In the cell below, we create 2 arrays: one for values of $x$ and one for function's value at each value of $x$. Run the code below *(press shift and enter at the same time)* to see the closer $x$ is to $2$, the more accurate the slope is.

# %%
#Load the libraries
import numpy as np

# Create an array of x values that approach a from below

a = 2  # Point of differentiation
x_values = np.linspace(1.5, 2, 25, endpoint=False)  # values of x starting at 1.5 to 2

# Define the function
def f(x):
    return x**2  # f(x) = x^2

# Compute slopes by using the definition 
def slope(x_values):
    return (f(x_values)-f(a))/(x_values-a)

y_values = [slope(x) for x in x_values]


print("Restults of limits:")
print("x \t Slopes")
for x, y in zip(x_values, y_values):
    print(f"{x:.3f}\t {y:.3f}")
# Out:
# Restults of limits:
# x 	 Slopes
# 1.500	 3.500
# 1.520	 3.520
# 1.540	 3.540
# 1.560	 3.560
# 1.580	 3.580
# 1.600	 3.600
# 1.620	 3.620
# 1.640	 3.640
# 1.660	 3.660
# 1.680	 3.680
# 1.700	 3.700
# 1.720	 3.720
# 1.740	 3.740
# 1.760	 3.760
# 1.780	 3.780
# 1.800	 3.800
# 1.820	 3.820
# 1.840	 3.840
# 1.860	 3.860
# 1.880	 3.880
# 1.900	 3.900
# 1.920	 3.920
# 1.940	 3.940
# 1.960	 3.960
# 1.980	 3.980

# %% [markdown]
# As the table shows, as $x$ values get closer and closer to 2, the slope of the secant line gets closer and closer to 4. If we want to the slope to get closer to the true value, try changing the following line of code to make x values even closer to 2:
#
# <code>x_values_left = np.linspace(1.5, 2, 25, endpoint=False)</code>
#
# **How can we do that?**
#
# There are a few options:
# 1. We could make more points - try 1,000 points!
# 2. We could make our interval smaller - instead of looking at (1.5,2), we could look at (1.9,2) with 20 points.
#
# Try those options out in the empty cell below and see if your table of values gets closer to 4!

# %% [markdown]
# <div style="width: 100%; height: 2px; background-color: #2c5364; margin: 20px 0;"></div>

# %% [markdown]
# # Now You Try!

# %% [markdown]
# <div style="background-color:#1e1e2f; color:white; padding:15px; border-radius:10px; font-family:'Segoe UI', sans-serif;">
#     <h2>Directions</h2>
#
# For the 2 questions below, use the code cell above to estimate the limit to find the slope of the tangent line for the given functions:
#
# $$\displaystyle\lim_{{x \to a}} \frac{f(x) - f(a)}{x-a}$$
#
# You should copy the code above and alter it to solve these problems.  You may need to use AI (like ChatGPT or Claude or another such application) to help you figure out how to write different functions in python. We hope this will be valuable experience to learn and practice prompt engineering and problem solving.
#
# <div style="width: 100%; height: 2px; background-color: #ccc; margin: 20px 0;"></div>
#
# For each question- Create a cell below the question
# - Copy code into the cell (make sure the cell is marked as Code)
# - Alter the code to match the function given and the point of interest
# - Use the resulting table to approximate the slope value
# - Write your results in a Markdown cell below your code for each problem
#
# </div>

# %% [markdown]
# <div style=" background-color:#f5f5f5; padding: 15px; border-left: 6px solid #2c5364;  ">
#   <div style="background: #203a43; color:white; padding: 15px; border-radius: 10px; font-family:'Segoe UI', sans-serif;">
#   <h2 style="margin:0;"> Question #1</h2>
# </div>
#
# Use the directions above to create code that will find the slope of tangent line of $g(x)=e^x$ at $x = 1$.
#
# <div style="width: 100%; height: 2px; background-color: #ccc; margin: 20px 0;"></div>
#
# Please remember to:
# - Create a cell below the question.
# - Copy code into the cell (make sure the cell is marked as Code).
# - Alter the code to match the function given and the point of interest.
# - Use the resulting table to approximate the slope of tangent line.
# </div>

# %% [markdown]
# <div style=" background-color:#f5f5f5; padding: 15px; border-left: 6px solid #2c5364;  ">
#   <div style="background: #203a43; color:white; padding: 15px; border-radius: 10px; font-family:'Segoe UI', sans-serif;">
#   <h2 style="margin:0;"> Question #2</h2>
# </div>
#
# Create code that will find the slope of tangent line of $k(x)=sin(x)$ at $x=\pi$.
#     <div style="width: 100%; height: 2px; background-color: #ccc; margin: 20px 0;"></div>
#
# Please remember to:
# - Create a cell below the question.
# - Copy code into the cell (make sure the cell is marked as Code).
# - Alter the code to match the function given and the point of interest.
# - Use the resulting table to approximate the slope of tangent line.
# </div>

# %% [markdown]
# <a id="section2"></a>
# <h1 style="border-left: 6px solid #2c5364; padding-left: 10px;">2. The Derivative of a Function at a Point</h1>

# %% [markdown]
# The **derivative** of a function represents the slope of the function at a given point, denoted by $f'(x)$. From Section 1, we learned that the slope at a point on a curve corresponds to the slope of the tangent line at that point. Therefore, finding the derivative at a point is equivalent to finding the slope of the tangent line there. The process of finding a derivative is called **differentiation**.
#
# From algebra we know a lot about slopes, but lets focus on a few of key properties of slopes:
# - Lines are straight and have constant slope
# - When the line has a positive slope, the function values are increasing and when the line has a negative slope, the function values are decreasing.
# - If we know any two points on a line, we can calculate the slope, $m$, using this formula: $m=\displaystyle\frac{y_2-y_1}{x_2-x_1}$

# %% [markdown]
# ![Screenshot%202025-06-16%20at%2012.18.44%E2%80%AFPM.png](attachment:Screenshot%202025-06-16%20at%2012.18.44%E2%80%AFPM.png)

# %% [markdown]
# <div style=" color: black; padding: 16px; border-radius: 10px; font-family:'Segoe UI', sans-serif; box-shadow: 0 0 10px #2c5364;">
#   <h2 style="margin:0;">Definition of Derivative</h2>
#
# Let $f(x)$ be a function defined is an open interval containing $a$. The derivative of the function $f(x)$ at $a$, denoted by $f'(x)$, is defined by:
#
# $$f'(a) = \displaystyle\lim_{x \to a} \frac{f(x)-f(a)}{x-a}$$
#
# provided this limit exists.
#
# Alternatively, we may also define the derivative of $f(x)$ at $a$ as:
#
# $$f'(a) = \displaystyle\lim_{h \to 0} \frac{f(a+h)-f(a)}{h}$$
#
# </div>

# %% [markdown]
# <div style="width: 100%; height: 2px; background-color: #2c5364; margin: 20px 0;"></div>

# %% [markdown]
# <h2> Example #2</h2>
#
# Consider function $f(x) = 4x^2 - x + 2$.
#
# a) Use the table to estimate $f'(2)$.
#
# b) Find $f'(2)$ by the equation for Definition of Derivative.

# %% [markdown]
# <h2> Solution </h2>
#
# For part **a**, copy the code in section 1 above to create the table:

# %%
#Load the libraries
import numpy as np

# Create an array of x values that approach a from below

a = 2  # Point of differentiation
x_values = np.linspace(1.5, 2, 25, endpoint=False)  # values of x starting at 1.5 to 2

# Define the function
def f(x):
    return 4*(x**2) - x + 2  # f(x) = 4x^2 - x + 2

# Compute slopes by using the definition 
def slope(x_values):
    return (f(x_values)-f(a))/(x_values-a)

y_values = [slope(x) for x in x_values]


print("Restults of limits:")
print("x \t Slopes")
for x, y in zip(x_values, y_values):
    print(f"{x:.3f}\t {y:.3f}")
# Out:
# Restults of limits:
# x 	 Slopes
# 1.500	 13.000
# 1.520	 13.080
# 1.540	 13.160
# 1.560	 13.240
# 1.580	 13.320
# 1.600	 13.400
# 1.620	 13.480
# 1.640	 13.560
# 1.660	 13.640
# 1.680	 13.720
# 1.700	 13.800
# 1.720	 13.880
# 1.740	 13.960
# 1.760	 14.040
# 1.780	 14.120
# 1.800	 14.200
# 1.820	 14.280
# 1.840	 14.360
# 1.860	 14.440
# 1.880	 14.520
# 1.900	 14.600
# 1.920	 14.680
# 1.940	 14.760
# 1.960	 14.840
# 1.980	 14.920

# %% [markdown]
# As the table shows, we conclude that as $x$ approaches to $2$, $f'(x)$ approaches to $15$.

# %% [markdown]
# For part **b**, using the definition of derivative:

# %% [markdown]
# <div style="display: flex; justify-content: space-between; width: 100%; font-family: 'Segoe UI', sans-serif;">
#
#   <div style="width: 48%;">
#     $f'(2) = \displaystyle\lim_{x \to 2} \frac{f(x)-f(2)}{x-2}$
#   </div>
#   <div style="width: 48%;">
#     Apply the definition
#   </div>
# </div>
#
# <div style="display: flex; justify-content: space-between; width: 100%; font-family: 'Segoe UI', sans-serif;">
#   <div style="width: 48%;">
#     $= \displaystyle\lim_{x \to 2} \frac{4x^2 - x + 2 - 16}{x - 2}$
#   </div>
#   <div style="width: 48%;">
#     Substitute $f(x) = 4x^2 - x + 2$, $f(2) = 16$
#   </div>
# </div>
#
# <div style="display: flex; justify-content: space-between; width: 100%; font-family: 'Segoe UI', sans-serif;">
#   <div style="width: 48%;">
#     $= \displaystyle\lim_{x \to 2} \frac{(4x + 7)(x - 2)}{x - 2}$
#   </div>
#   <div style="width: 48%;">
#     Simplify and factor numerator
#   </div>
# </div>
#
# <div style="display: flex; justify-content: space-between; width: 100%; font-family: 'Segoe UI', sans-serif;">
#   <div style="width: 48%;">
#     $= \displaystyle\lim_{x \to 2}  (4x + 7)$
#   </div>
#   <div style="width: 48%;">
#     Cancel the common factor
#   </div>
# </div>
#
# <div style="display: flex; justify-content: space-between; width: 100%; font-family: 'Segoe UI', sans-serif;">
#   <div style="width: 48%;">
#     $= 15$
#   </div>
#   <div style="width: 48%;">
#     Evaluate the limit
#   </div>
# </div>

# %% [markdown]
# <a id = "strategy"></a>
# <div style="border: 3px solid; border-image: linear-gradient(to right, #001f4d, #7f00ff) 1; padding: 15px; border-radius: 12px; font-family:'Segoe UI', sans-serif;">
#     <h2>Strategy: How to find the derivative of function at a point by using the definition</h2>
#
# <div style="width: 100%; height: 2px; background-color: #ccc; margin: 20px 0;"></div>
#     Consider function $f(x)$, here are the steps to find the derivative $f'(x)$ at $x = a$ by using the limit:
#
# 1. Evaluate the value $f(a)$
#
# 2. Apply the definition:
#
# $$f'(a) = \displaystyle\lim_{x \to a} \frac{f(x)-f(a)}{x-a}$$
#
# 3. Substitute $f(x)$, $f(a)$, and $a$.
#
# 4. Simplify and factor numerator if needed
#
# 5. Evaluating the limit by replacing $a$ to the formula
#
# <div style="width: 100%; height: 2px; background-color: #ccc; margin: 20px 0;"></div>
#
# <h3>Solution in Python </h3>
#
# You need to alter this code (type value of $a$ in step #1 and function $f(x)$ in step #2)
#
# <div style="background: linear-gradient(to right, #0f2027, #203a43, #2c5364); color:white; padding: 15px; border-radius: 10px; font-family:'Segoe UI', sans-serif; margin-top: 10px">
#
# #Load the libraries
#
# import numpy as np
#
# #Step 1: Create an array of $x$ values that approach $a$ from below
#
# a = <span style="background: #ccc; color: black">type value of a here</span>
#
# x_values = np.linspace(a-0.5, a, 25, endpoint=False)  # values of x starting at $a-0.5$ to $a$
#
# #Note that you can adjust the range of $a$ by adjusting the value of *start* and *end* of function np.linspace(start, end) above
#
# #Step 2: Define the function
#
# def f(x):
#
# <span style="background: #ccc; color: black; margin-left: 20px">return #type your function here</span>
#
# #Step 3: Compute slopes by using the definition
#
# def slope(x_values):
#
# <span style="margin-left: 20px"> return (f(x_values)-f(a))/(x_values-a)</span>
#
# y_values = [slope(x) for x in x_values]
#
# #Step 4: Print the result
# print("Restults of limits:")
#
# print("x \t Slopes")
#
# for x, y in zip(x_values, y_values):
#
# <span style="margin-left: 20px">  print(f"{x:.3f}\t {y:.3f}")</span>
#
# </div>
#
#
# </div>

# %% [markdown]
# # Now you try

# %% [markdown]
# <div style="background-color:#1e1e2f; color:white; padding:15px; border-radius:10px; font-family:'Segoe UI', sans-serif;">
#     <h2>Directions</h2>
#
# For the 2 questions below, follow the [Strategy: How to find the derivative of function at a point by using the definition](#strategy) above to estimate the limit of the function for part **a** and use the definition of derivative to find the $f'(x)$ for part **b**:
#
# $$f'(a) = \displaystyle\lim_{{x \to a}} \frac{f(x) - f(a)}{x-a}$$
#
# You should copy the code above and alter it to solve these problems.  You may need to use AI (like ChatGPT or Claude or another such application) to help you figure out how to write different functions in python. We hope this will be valuable experience to learn and practice prompt engineering and problem solving.
#
# <div style="width: 100%; height: 2px; background-color: #ccc; margin: 20px 0;"></div>
#
# For each question- Create a cell below the question
# - Copy code into the cell (make sure the cell is marked as Code)
# - Alter the code to match the function given and the point of interest
# - Use the resulting table to approximate the slope value
# - Write your results in a Markdown cell below your code for each problem
#
# </div>

# %% [markdown]
# <div style=" background-color:#f5f5f5; padding: 15px; border-left: 6px solid #2c5364;  ">
#   <div style="background: #203a43; color:white; padding: 15px; border-radius: 10px; font-family:'Segoe UI', sans-serif;">
#   <h2 style="margin:0;"> Question #3</h2>
# </div>
#
#
# Consider function $f(x) = x^3 - 2x^2 + x - 1$.
#
# a) Use a table to estimate $f'(3)$
#
# b) Use the definition of derivative to find $f'(3)$
#     <div style="width: 100%; height: 2px; background-color: #ccc; margin: 20px 0;"></div>
#
# Please create two cells below this box and type your code for part **a** and write your results in a Markdown cell  for part **b**
#
# </div>

# %% [markdown]
# <div style=" background-color:#f5f5f5; padding: 15px; border-left: 6px solid #2c5364;  ">
#   <div style="background: #203a43; color:white; padding: 15px; border-radius: 10px; font-family:'Segoe UI', sans-serif;">
#   <h2 style="margin:0;"> Question #4</h2>
# </div>
#
#
# Consider function $f(x) = 5x^4 - 2x^2 + x - 1$.
#
# a) Use a table to estimate $f'(2)$
#
# b) Use the definition of derivative to find $f'(2)$
#     <div style="width: 100%; height: 2px; background-color: #ccc; margin: 20px 0;"></div>
#
# Please create two cells below this box and type your code for part **a** and write your results in a Markdown cell  for part **b**
#
# </div>

# %% [markdown]
# <a id="section3"></a>
# <h1 style="border-left: 6px solid #2c5364; padding-left: 10px;">3. Equation of Tangent line</h1>

# %% [markdown]
# In Section 1, we learned what a tangent line is, and in Section 2, we explored how to use the derivative of a function $f(x)$ to find the slope of the tangent line at a point. Now, a natural question arises: How can we find the full equation of the tangent line at a specific point on the graph of a function?
#
# Let see the definition below:

# %% [markdown]
# <div style=" color: black; padding: 16px; border-radius: 10px; font-family:'Segoe UI', sans-serif; box-shadow: 0 0 10px #2c5364;">
#   <h2 style="margin:0;">Equation of Tangent line</h2>
#
#    Let $f(x)$ be a differentable function and $a$ a point in its domain. The slope of the tangent line at $x=a$ is given by the derivative $f'(a)$. The point of tangency is $(a,f(a))$. The equation of the tangent line is derived using the point-slope form of a line:
#
# $$y - f(a) = f'(a)(x-a)$$
#
# Or equivalently,
#
# $$y = f'(a)(x-a)+f(a)$$
#
#
#
# </div>

# %% [markdown]
# <div style="width: 100%; height: 2px; background-color: #2c5364; margin: 20px 0;"></div>

# %% [markdown]
# <h2> Example #3</h2>
#
# **Find the equation of tangent line to $f(x) = x^2$ at $x=3$.**
#
# <h2> Solution </h2>
#
# - Compute $f(3)$:
#
# $$f(x)= 3^2 = 9$$
#
# - Compute the derivative $f'(x)$:
#
# $$f'(x) = 2x \implies f'(3) = 2(3) = 6$$
#
# - Use the point-slope formula:
#
# $$y-9 = 6(x-3) \implies y = 6x - 9$$
#
# **Final Asnwer**: The equation of tangent line is $y = 6x - 9$

# %% [markdown]
# <h2>Python </h2>
#
# Let's use Python and SymPy to compute the tangent line to $f(x) = x^2$ at $x=3$

# %%
import sympy as sp

# Define the variable
x = sp.Symbol('x')

# Define the function f(x) = x^2
def f(x):
    return x**2

# Define the point of tangency
a = 3
fa = f(a) #f(3)

# Compute the derivative symbolically
f_expr = f(x)
f_prime = sp.diff(f_expr, x) #using .diff() to find derivative of function
slope = f_prime.subs(x, a) #substitute a to f(x) to find the slope f'(a) at x=a

# Write the tangent line: y = f'(a)(x - a) + f(a)
tangent_line = slope * (x - a) + fa

# Display results
print("Function:", f_expr)
print("Derivative:", f_prime)
print("Point of tangency: ({}, {})".format(a,fa))
print("Slope of tangent line:", slope)
print("Equation of tangent line:", tangent_line)
# Out:
# Function: x**2
# Derivative: 2*x
# Point of tangency: (3, 9)
# Slope of tangent line: 6
# Equation of tangent line: 6*x - 9

# %% [markdown]
# Let's explore how we can draw the plot of function $f(x)$ and its tangent line at $x=3$ by using matplotib and numpy from Python

# %%
import numpy as np
import matplotlib.pyplot as plt
import sympy as sp

# Symbolic setup
x = sp.Symbol('x')

# Define the function
def f(x):
    return x**2

# Point of tangency
a = 3
fa = f(a)

# Derivative (slope of tangent line)
f_expr = f(x)
f_prime = sp.diff(f_expr, x)
slope = f_prime.subs(x, a)

# Tangent line equation: y = slope * (x - a) + f(a)
def tangent_line(x_val):
    return slope * (x_val - a) + fa

# Generate x-values for plotting
x_vals = np.linspace(0, 6, 400)
f_vals = f(x_vals)
tan_vals = tangent_line(x_vals)

# Plotting
plt.figure(figsize=(8, 5))
plt.plot(x_vals, f_vals, label='$f(x) = x^2$', color='blue')
plt.plot(x_vals, tan_vals, label='Tangent at $x=3$', color='red', linestyle='--')
plt.scatter(a, fa, color='black')  # Point of tangency
plt.text(a, fa + 1, f'({a}, {fa})', ha='center')

plt.title('Graph of $f(x) = x^2$ and its Tangent Line at $x = 3$')
plt.xlabel('x')
plt.ylabel('y')
plt.legend()
plt.grid(True)
plt.axhline(0, color='gray', lw=0.5)
plt.axvline(0, color='gray', lw=0.5)
plt.show()

# %% [markdown]
# <div style="width: 100%; height: 2px; background-color: #2c5364; margin: 20px 0;"></div>

# %% [markdown]
# This interactive tool helps you visualize the concept of a tangent line to the curve $f(x)=x^2$.
#
# Use the slider labeled “x-coordinate” to choose the point on the curve where you'd like to draw the tangent line. As you move the slider, the red dot shows the selected point, and the orange dashed line updates to show the tangent line at that point. This visually demonstrates how the slope of the tangent line changes depending on where you are along the curve.
#
# This is a great way to connect geometric intuition with calculus concepts like derivatives and instantaneous rate of change.

# %%
import numpy as np
import matplotlib.pyplot as plt
from ipywidgets import interact, FloatSlider
# %matplotlib inline

# Define the function and its derivative
def f(x):
    return x**2

def f_prime(x):
    return 2*x

# Plotting function with adjustable tangent point
def plot_tangent(x_val):
    fig, ax = plt.subplots(figsize=(8, 5))

    # Plot the function
    x = np.linspace(-1, 3, 300)
    y = f(x)
    ax.plot(x, y, label=r"$f(x) = x^2$", color='darkblue', linewidth=2)

    # Plot the tangent line
    slope = f_prime(x_val)
    y_tangent = slope * (x - x_val) + f(x_val)
    ax.plot(x, y_tangent, '--', color='orange', linewidth=2, label='Tangent Line')

    # Mark the point of tangency
    ax.plot(x_val, f(x_val), 'ro', label=f'Tangent at x = {x_val:.2f}')

    # Labels, grid, and fixed axis limits
    ax.set_title("Tangent Line to $f(x) = x^2$", fontsize=14)
    ax.set_xlabel("x")
    ax.set_ylabel("f(x)")
    ax.set_xlim([-1, 3])  # Fix x-axis range
    ax.set_ylim([-1, 10])  # Fix y-axis range
    ax.legend()
    ax.grid(True, linestyle='--', alpha=0.5)
    plt.show()

# Create the slider for x-value
x_slider = FloatSlider(value=1.0, min=-1, max=3, step=0.1, description='x-coordinate:')
interact(plot_tangent, x_val=x_slider);
# Out:
# interactive(children=(FloatSlider(value=1.0, description='x-coordinate:', max=3.0, min=-1.0), Output()), _dom_…

# %% [markdown]
# <a id = "strategy_tangent_line"></a>
# <div style="border: 3px solid; border-image: linear-gradient(to right, #001f4d, #7f00ff) 1; padding: 15px; border-radius: 12px; font-family:'Segoe UI', sans-serif;">
#     <h2>Strategy: Find the Equation of Tangent Line</h2>
#
# <div style="width: 100%; height: 2px; background-color: #ccc; margin: 20px 0;"></div>
#     Here is the step by step to find <b>the equation of tangent line</b> for function $f(x)$ at the point $x=a$:
#
# - Compute $f(a)$: substitute $a$ to $x$ in function $f(x)$.
#
# - Find the derivative $f'(a)$: Compute the derivative $f'(x)$, then substitute $x=a$ to find $f'(a)$
#
# - Use the point-slope formula: $y - f(a) = f'(a)(x-a)$
#
#
# <div style="width: 100%; height: 2px; background-color: #ccc; margin: 20px 0;"></div>
#
# <h3>Solution in Python </h3>
#
# You need to alter this code: type function $f(x)$ in step #2 and value of the point of tangency $a$ in step #3
#
# <div style="background: linear-gradient(to right, #0f2027, #203a43, #2c5364); color:white; padding: 15px; border-radius: 10px; font-family:'Segoe UI', sans-serif; margin-top: 10px">
#
#
#
# import sympy as sp
#
# #Step 1: Define the variable and function $f(x)$
#
# x = sp.Symbol('x')
#
# def f(x):
#
# <span style="background : #ccc; color: black; margin-left: 20px">return #type your function here</span>
#
# #Step 2: Define the point of tangency
#
# a = <span style="background : #ccc; color: black;">#type value of $a$ here</span>
#
# fa = f(a)
#
# #Step 3: Compute the derivative symbolically
#
# f_expr = f(x)
#
# f_prime = sp.diff(f_expr, x) #using .diff() to find derivative of function
#
# slope = f_prime.subs(x, a) #substitute a to f(x) to find the slope f'(a) at x=a
#
# #Step 4: Write the tangent line: y = f'(a)(x - a) + f(a)
#
# tangent_line = slope * (x - a) + fa
#
# #Step 5: Display results
#
# print("Function:", f_expr)
#
# print("Derivative:", f_prime)
#
# print("Point of tangency: ({}, {})".format(a,fa))
#
# print("Slope of tangent line:", slope)
#
# print("Equation of tangent line:", tangent_line)
#
#
# </div>

# %% [markdown]
# # Now you try

# %% [markdown]
# <div style="background-color:#1e1e2f; color:white; padding:15px; border-radius:10px; font-family:'Segoe UI', sans-serif;">
#     <h2>Directions</h2>
#
# For the 2 questions below, follow the [Strategy: Find the Equation of Tangent Line](#strategy_tangent_line) to find the equation of tangent line for each function $f(x)$ at the point $x=a$.
#
# $$y - f(a) = f'(a)(x-a)$$
#
# You should copy the code above and alter it to solve these problems.  You may need to use AI (like ChatGPT or Claude or another such application) to help you figure out how to write different functions in python. We hope this will be valuable experience to learn and practice prompt engineering and problem solving.
#
# <div style="width: 100%; height: 2px; background-color: #ccc; margin: 20px 0;"></div>
#
# For each question- Create a cell below the question
# - Copy code into the cell (make sure the cell is marked as Code)
# - Alter the code to match the function given and the point of tangency
# - Write your results in a Markdown cell below your code for each problem
#
# </div>

# %% [markdown]
# <div style=" background-color:#f5f5f5; padding: 15px; border-left: 6px solid #2c5364;  ">
#   <div style="background: #203a43; color:white; padding: 15px; border-radius: 10px; font-family:'Segoe UI', sans-serif;">
#   <h2 style="margin:0;"> Question #5</h2>
# </div>
#
#
# Find the equation of tangent line to function $f(x) = \frac{1}{x}$ at $x=2$.
#
# <div style="width: 100%; height: 2px; background-color: #ccc; margin: 20px 0;"></div>
#
# Please follow the Summary and the Example #3 above and create two cells below this box. For the first cell, write your result in a Markdown cell. For the second cell, copy and alter the code from Summary and Example above.
#
# </div>

# %% [markdown]
# <div style=" background-color:#f5f5f5; padding: 15px; border-left: 6px solid #2c5364;  ">
#   <div style="background: #203a43; color:white; padding: 15px; border-radius: 10px; font-family:'Segoe UI', sans-serif;">
#   <h2 style="margin:0;"> Question #6</h2>
# </div>
#
#
# Find the equation of tangent line to function $f(x) = x^2+3x+2$ at $x=1$.
#
# <div style="width: 100%; height: 2px; background-color: #ccc; margin: 20px 0;"></div>
#
# Please follow the Summary and the Example #3 above and create two cells below this box. For the first cell, write your result in a Markdown cell. For the second cell, copy and alter the code from Summary and Example above.
#
# </div>
