# %% [markdown]
# # Icebreaker with Python

# %% [markdown]
# This notebook is meant to introduce you to Jupyter Notebooks and the python coding language.
#
# *If you need to submit as PDF and standard PDF export fails, try **File → Save and Export Notebook As** and choose **webpdf**.*
#
# The goals are:
# 1. to understand better what Jupyter Notebooks can do to help us learn calculus
# 2. to get comfortable with reading and creating code using the python programming language
# 3. to talk about why programming is useful and how we can use AI to help create code
#
# **If you click into this cell and then press both `"shift"` and `"enter"` (at the same time), you will be able to see the text as I would like you to see it**

# %% [markdown]
# You may notice that this cell is labeled as ***Markdown*** and the next cell is labeled as ***Code***. You can tell by clicking on this cell and then looking upward from about the middle of this cell, along the top of the notebook frame. This is an indication of what you are meant to do in each cell - if you are meant to write code, it should be labeled as ***Code*** and if you are writing text, it should be labeled ***Markdown***.
#
# You can probably see that there is no readable text in the cell below, rather it is a list of commands telling the notebook to import different libraries of functions so that we can use these libraries for the rest of this notebook.  One such collection of functions is **`numpy`** and another is **`sympy`**, which are math libraries that allow us to do calculations and to use symbolic language associated with math. You will also see `matplotlib.pyplot` - can you guess what this will do?  We will see later in this assignment!
#
# To make sure that the libraries are functioning, we need to click into the cell below and press both `"Shift"` and `"Enter"` at the same time OR we can click the arrow pointing to the right along the top of this frame (it looks like a "play" symbol). Please click into the next cell and press both `"Shift"` and `"Enter"` at the same time. You will know if it worked because a number (like `1` or `2`) should appear in the [ ] next to the cell (if it is the first time you ran the code in the cell).  Once we have run the cell below, we can use "np" and "sym" and "plt" in any code cells beneath it.
#
# **Remember! If you click into this cell and then press both `"Shift"` and `"Enter"`, you will be able to see the text as I would like you to see it**

# %%
import numpy as np
import sympy as sym
import matplotlib.pyplot as plt

# better image resolution
import matplotlib_inline.backend_inline
matplotlib_inline.backend_inline.set_matplotlib_formats('svg')

# %% [markdown]
# Now that we have our libraries set up, lets see what we can do with them.  Please run the next TWO cells of code by clicking into each cell and pressing both "shift" and "enter" at the same time.
#
# <div class="alert alert-block alert-info">
#     <h2>Notice:</h2>
#     <p style="font-size:20px">
#         When you are instructed to <b>"run the code"</b>, this always means to click into the cell with the code and press both <code>"Shift"</code> and <code>"Enter"</code> at the same time. <b>We do this for ALL of the cells - both markdown and code.</b>
#     </div>

# %%
# x-axis grid for variable x1
x1 = np.linspace(1,10,5)

# %%
x1

# %% [markdown]
# Now that you have run the code in the cells above, please explain what that code did in each cell as best as you are able.  For this assignment, I will try to remember to label any questions/problems I want you to answer/complete by numbering them:
# ## Question #1, Question #2, Question #3, etc.
# I hope this will help you understand when I want you to respond.

# %% [markdown]
# <h2 class="alert alert-block alert-success">Question <b>#1</b></h2>

# %% [markdown]
# What did the code above do? **Please create a cell below and type out your answer.** For the cell you create, be sure to mark it as **Markdown** (not Code)—use a Markdown cell for text answers to avoid syntax errors.

# %% [markdown]
# <h2 class="alert alert-block alert-success">Question <b>#2</b></h2>

# %% [markdown]
# If we run the code below, what do you think it will do?  Feel free to run it if you aren't yet sure or to verify your response and write your answer after.  Why do you think there is only 1 cell instead of the 2 cells above? **Please create a cell below and type out your answer. For the cell you create, be sure to mark it as "markdown" or "code" appropriately.**

# %%
# x-axis grid for variable x2
x2 = np.linspace(1,10,10)
x2

# %% [markdown]
# In Python, a collection of numbers like x1 and x2 is called an array.  In the previous example, x2 is an array of 10 equally spaced numbers that start at 1 and go to 10.  These could be useful for graphing; if you think of a graph that you have created in algebra before, these could be x-values that we use to plug into a function to plot the graph.  We will do that later in the assignment!
#
# This time, I would like YOU to write the code.  Please note that you are able to click into any of the cells above and copy and paste code into a new cell, then alter it.
#
# We will use the arrays you create in the following questions later in this assignment.

# %% [markdown]
# <h2 class="alert alert-block alert-success">Question <b>#3</b></h2>

# %% [markdown]
# Write code that will create an array of 20 points from -10 to 10.  Please call this collection of points x3. *You do not have to have the code display x3, but you can if you'd like to check that you did it correctly!*  **Please use the cell below and type out your answer. For the cell you create, be sure to mark it as *"Markdown"* or *"Code"* appropriately.**

# %%
# Type your code in here!  You may delete what I wrote in here. You may use separate cells of put all of the code in 1 cell.  
# Feel free to play around with it!  Can you see how to add more cells?  Can you see how to copy the code in different ways?

# %% [markdown]
# <h2 class="alert alert-block alert-success">Question <b>#4</b></h2>

# %% [markdown]
# Write code that will create an array of 100 points from -10 to 10.  Please call this collection of points x4.  *You do not have to have the code display x3, but you can if you'd like to check that you did it correctly!* **Please use the cell below and type out your answer. For the cell you create, be sure to mark it as *"Markdown"* or *"Code"* appropriately.**

# %% [markdown]
# <h2 class="alert alert-block alert-success">Question <b>#5</b></h2>

# %% [markdown]
# Write code that will create an array of 1000 points from -10 to 10.  Please call this collection of points x5.  *You do not have to have the code display x3, but you can if you'd like to check that you did it correctly!* **Please use the cell below and type out your answer. For the cell you create, be sure to mark it as *"Markdown"* or *"Code"* appropriately.**

# %% [markdown]
# When you are ready, check out the code below.  What do you think it does?

# %%
# function
fx = x1**2

# display function values
fx

# %% [markdown]
# <h2 class="alert alert-block alert-success">Question <b>#6</b></h2>

# %% [markdown]
# Explain what the code in the cell above does.  What did you learn about what "**" does in python?  What is the function fx?  **Please use the cell below and type out your answer. For the cell you create, be sure to mark it as *"Markdown"* or *"Code"* appropriately.**

# %% [markdown]
# <h2 class="alert alert-block alert-success">Question <b>#7</b></h2>

# %% [markdown]
# Take a look at the code below and see if you can guess what it will do.  If you're not sure, run the code and explain what you see by creating a cell below the output from the code below.

# %%
#display the graph of the function fx, where x1 is the domain
plt.plot(x1, fx);

# %% [markdown]
# <h2 class="alert alert-block alert-success">Question <b>#8</b></h2>

# %% [markdown]
# The graph above should be the graph of $f(x)=x^2$.   Does the graph above look right?  What is wrong with this graph?  Do you know how to fix it?
# If you are unsure if the graph is right, you can try to graph it using **[Desmos Graphing Calculator](https://www.desmos.com/calculator)**, if that helps.
# **Please use the cell below and type out your answer. For the cell you create, be sure to mark it as *"Markdown"* or *"Code"* appropriately.**

# %% [markdown]
# To help fix this graph, we could try using more points, like the following code.  Run it and see if it's better.

# %%
# function
fx = x2**2

#display the graph of the function fx, where x2 is the domain
plt.plot(x2, fx);

# %% [markdown]
# The graph looks a bit better in that it is more smoothly connected with more points, however it is missing the left side - the **x-values less than 0**.  When we create graphs, we want to ensure that any *interesting spots* are included.  Interesting spots are places where we have local maximum/minimum values, gaps in the graph, zeros, etc.

# %% [markdown]
# <h2 class="alert alert-block alert-success">Questions <b>#10</b>, <b>#11</b>, and <b>#12</b></h2>

# %% [markdown]
# Recall that you created **3 arrays of points from $-10$ to $10$ and named them `x3`, `x4`, and `x5`**. Take a moment to write the code for making the graphs of `fx` using `x3`, `x4`, and `x5` as the inputs. I will be looking for 3 graphs. Again, feel free to copy the code from any useful cells.  You should run your code to makesure it works!
#
#
# > *HINT: you will need to run the code where you created the arrays for x3, x4, and x5 if you want to use them in the graphs you create!*

# %%
#Please use this cell to create the graph using x3 - This is #10

# %%
#Please use this cell to create the graph using x4 - This is #11

# %%
#Please use this cell to create the graph using x5 - This is #12

# %% [markdown]
# <h2 class="alert alert-block alert-success">Question <b>#13</b></h2>

# %% [markdown]
# What have you learned about creating graphs with Python and the number of points you use?  Write down anything else you think is worth remembering. **Please use the cell below and type out your answer. For the cell you create, be sure to mark it as *"Markdown"* or *"Code"* appropriately.**

# %% [markdown]
# Let's create another function to play with.  In the cell below I define $g(x)=1/x$.  Are you familiar with that graph?  Let's see what it looks like using x1 as inputs, then x2.

# %%
# define function gx
gx = 1/x1

#display the graph of the function gx, where x1 is the domain
plt.plot(x1, gx);

# %%
# define function gx
gx = 1/x2

#display the graph of the function gx, where x1 is the domain
plt.plot(x2, gx);

# %% [markdown]
# Just like with $f(x)=x^2$, the graph is not smooth and it is missing all negative x values.

# %% [markdown]
# <h2 class="alert alert-block alert-success">Questions <b>#14</b>, <b>#15</b>, and <b>#16</b></h2>

# %% [markdown]
# Try creating the graph of g(x) using the three arrays you made.

# %%
#Please use this cell to create the graph using x3 - This is #14

# %%
#Please use this cell to create the graph using x4 - This is #15

# %%
#Please use this cell to create the graph using x5 - This is #16

# %% [markdown]
# <h2 class="alert alert-block alert-success">Questions <b>#16</b></h2>

# %% [markdown]
# Do you notice anything interesting about the graphs you created?  Are they accurate?
#
# If you are unsure, try going to
# **[Desmos Graphing Calculator](https://www.desmos.com/calculator)**
# and graphing $g(x)=1/x$
#
# What is different about the graph in Desmos and the graphs you created?  Do you know why our graphs look the way they do?
# **Please create a cell below this one to answer question #16.  Be sure to label it correctly.**

# %% [markdown]
# Try running the next cell with code to consider what might be going on.  There is an error message that might help you understand!

# %%
# x-axis grid for variable x1
t = np.linspace(-10,10,999)

# define function gx
gx = 1/t

#display the graph of the function gx, where x1 is the domain
plt.plot(t, gx)

#display the graph of the function gx, where x1 is the domain
plt.plot(t, gx)

plt.axhline(0, color='blue', linewidth=0.8, linestyle='--')  # x-axis
plt.axvline(0, color='blue', linewidth=0.8, linestyle='--')  # y-axis
plt.grid(color='gray', linestyle='--', linewidth=0.5, alpha=0.7) # grid lines
plt.ylim(-10, 10)

# %% [markdown]
# <h2 class="alert alert-block alert-success">Question <b>#17</b></h2>

# %% [markdown]
# For this last *coding* task, I would like you to combine all of what we have learned and:
# 1) create an array of x-values, named whatever variable you'd like (but please note that if you reuse any of the above variables, they will be overwritten).
# 2) declare a function - pick your favorite function!  Or any function that you feel good about
# 3) create a plot of the function you chose
#
# Please be sure to include any interesting spots.  If you are uncertain, please feel free to use **[Desmos Graphing Calculator](https://www.desmos.com/calculator)** to check your work!  Remember if your function is too simple, it won't be fun!!
#
# **Please create a box below this one to put all of your code in.  If you'd like to use the x-axis and y-axis lines and the grid from the previous plot, feel free to copy and paste!**

# %% [markdown]
# <h2 class="alert alert-block alert-success">Question <b>#18</b></h2>

# %% [markdown]
# **Last One!** The last thing I would like you to do is to write about why programming is useful and how we can use AI to help create code.  We will talk about this together, but if you get here quickly, feel free to do a search or go to your favorite AI and pose the same question.  In your search (or in your AI prompt), you can tie it specifically to your major, if you know what you want to do!
#
# **This time, try using a shortcut to create a new cell below.  If you click on the previous cell you will see a vertical blue bar on the left side of the screen. Click on that bar, then press the letter "b" on the keyboard. This should create a new cell below this one!**
